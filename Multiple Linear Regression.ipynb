# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('ToyotaCorolla - MLR.csv')
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
fig,axes = plt.subplots(2,2,figsize=(15,10))
axes[0,0].hist(df['Price'],edgecolor='black')
axes[0,0].set_title('Price')
axes[0,0].set_xlabel('Car Price Range')
axes[0,0].set_ylabel('No. of Cars')

axes[0,1].boxplot(df['Age_08_04'])
axes[0,1].set_title('Boxplot of Age of the car')

axes[1,0].violinplot(df['KM'])
axes[1,0].set_title('Violinplot of Kilometers of the car')

axes[1,1].boxplot(df['Weight'])
axes[1,1].set_title('Boxplot of Weight')
plt.suptitle('Dashboard')
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
sns.barplot(df['Automatic'].value_counts(),color='teal',edgecolor='black',ax=axes[0, 0])
plt.title('Automatic and Manual Cars')
plt.ylabel('Cars')


sns.barplot(df['cc'].value_counts(),color='indigo',edgecolor='black',ax=axes[0,1])
plt.title('Barchart of Cylinder Volume in cubic centimeters')
plt.ylabel('Cars')


sns.barplot(df['Gears'].value_counts(),edgecolor='black',color='cyan',ax=axes[1,0])
plt.title('Barchart of Gears of the cars')
plt.ylabel("Cars")

sns.barplot(df['Doors'].value_counts(),edgecolor='black',ax=axes[1,1])
plt.title('Barchart for Number of Doors of the car')
plt.ylabel('Cars')
plt.suptitle('Barchart Dashboard')
plt.show()

# %%
sns.barplot(df['HP'].value_counts(),color='brown',edgecolor='black')
plt.title('Horsepower')
plt.ylabel('Cars')
plt.show()

# %%
df.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc',
#        'Doors', 'Cylinders', 'Gears', 'Weight'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1435.000000  1435.000000    1435.000000  1435.000000  1435.000000
# mean   10720.915679    55.980488   68571.782578   101.491986     0.055749
# std     3608.732978    18.563312   37491.094553    14.981408     0.229517
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63451.000000   110.000000     0.000000
# 75%    11950.000000    70.000000   87041.500000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                  cc        Doors  Cylinders        Gears       Weight
# count   1435.000000  1435.000000     1435.0  1435.000000  1435.000000
# mean    1576.560976     4.032753        4.0     5.026481  1072.287108
# std      424.387533     0.952667        0.0     0.188575    52.251882
# ...

# %%
df_clean = df.drop(columns='Cylinders') #Cyclinders column contains only 4 hence it is not required for us.

# %%
df_clean
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  Gears  \
# 0     13500         23  46986    Diesel   90          0  2000      3      5
# 1     13750         23  72937    Diesel   90          0  2000      3      5
# 2     13950         24  41711    Diesel   90          0  2000      3      5
# 3     14950         26  48000    Diesel   90          0  2000      3      5
# 4     13750         30  38500    Diesel   90          0  2000      3      5
# ...     ...        ...    ...       ...  ...        ...   ...    ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3      5
# 1432  10845         72  19000    Petrol   86          0  1300      3      5
# 1433   8500         71  17016    Petrol   86          0  1300      3      5
# 1434   7250         70  16916    Petrol   86          0  1300      3      5
# 1435   6950         76      1    Petrol  110          0  1600      5      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df_clean['Fuel_Type'] = encoder.fit_transform(df_clean['Fuel_Type']) # 0 - CNG ; 1 - Diesel ; 2 - Petrol
df_clean['HP'] = encoder.fit_transform(df_clean['HP'])
df_clean['Doors'] = encoder.fit_transform(df['Doors'])
df_clean['Gears'] = encoder.fit_transform(df['Gears'])
df_clean['cc'] = encoder.fit_transform(df['cc'])
df_clean
# Out:
#       Price  Age_08_04     KM  Fuel_Type  HP  Automatic  cc  Doors  Gears  \
# 0     13500         23  46986          1   5          0  11      1      2
# 1     13750         23  72937          1   5          0  11      1      2
# 2     13950         24  41711          1   5          0  11      1      2
# 3     14950         26  48000          1   5          0  11      1      2
# 4     13750         30  38500          1   5          0  11      1      2
# ...     ...        ...    ...        ...  ..        ...  ..    ...    ...
# 1431   7500         69  20544          2   4          0   0      1      2
# 1432  10845         72  19000          2   4          0   0      1      2
# 1433   8500         71  17016          2   4          0   0      1      2
# 1434   7250         70  16916          2   4          0   0      1      2
# 1435   6950         76      1          2   9          0   6      3      2
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_norm = df_clean.copy()
df_norm['KM'] = scaler.fit_transform(df[['HP']])
df_norm['Age_08_04'] = scaler.fit_transform(df[['Age_08_04']])
df_norm['Weight'] = scaler.fit_transform(df[['Weight']])
df_norm
# Out:
#       Price  Age_08_04        KM  Fuel_Type  HP  Automatic  cc  Doors  Gears  \
# 0     13500  -1.777268 -0.767351          1   5          0  11      1      2
# 1     13750  -1.777268 -0.767351          1   5          0  11      1      2
# 2     13950  -1.723380 -0.767351          1   5          0  11      1      2
# 3     14950  -1.615603 -0.767351          1   5          0  11      1      2
# 4     13750  -1.400049 -0.767351          1   5          0  11      1      2
# ...     ...        ...       ...        ...  ..        ...  ..    ...    ...
# 1431   7500   0.701602 -1.034441          2   4          0   0      1      2
# 1432  10845   0.863267 -1.034441          2   4          0   0      1      2
# 1433   8500   0.809379 -1.034441          2   4          0   0      1      2
# 1434   7250   0.755490 -1.034441          2   4          0   0      1      2
# 1435   6950   1.078821  0.568103          2   9          0   6      3      2
#
#         Weight
# 0     1.774964
# ...

# %%
df_norm.corr()
# Out:
#               Price  Age_08_04        KM  Fuel_Type        HP  Automatic  \
# Price      1.000000  -0.876273  0.314134  -0.015883  0.224074   0.033928
# Age_08_04 -0.876273   1.000000 -0.155293   0.076382 -0.094661   0.031354
# KM         0.314134  -0.155293  1.000000   0.411973  0.906167   0.013313
# Fuel_Type -0.015883   0.076382  0.411973   1.000000  0.437901   0.069456
# HP         0.224074  -0.094661  0.906167   0.437901  1.000000   0.017437
# Automatic  0.033928   0.031354  0.013313   0.069456  0.017437   1.000000
# cc         0.189455  -0.158829  0.188187  -0.533680  0.240398  -0.063874
# Doors      0.183604  -0.146929  0.091803  -0.025339  0.132023  -0.027492
# Gears      0.063831  -0.005629  0.209642   0.069560  0.107709  -0.098582
# Weight     0.575869  -0.466484  0.087143  -0.502479  0.025358   0.058499
#
#                  cc     Doors     Gears    Weight
# Price      0.189455  0.183604  0.063831  0.575869
# Age_08_04 -0.158829 -0.146929 -0.005629 -0.466484
# ...

# %%
# Age and Price are negative related 
plt.title('Relation Between Price and Age of the Car')
plt.scatter(df['Price'],df['Age_08_04'],color = 'yellow',edgecolor='black')
plt.xlabel('Price')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# # First Model

# %%
x = df_norm.drop(columns = 'Price')
y = df_norm['Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
y_pred_train = model.predict(x_train)
y_pred_train
# Out:
# array([ 7569.86271679,  7939.74384652, 11787.88592904, ...,
#         7456.23368695, 10578.2240447 , 10145.31953059])

# %%
y_pred_test = model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_pred_test,y_test)
# Out:
# 0.8679043725227985

# %%
# We got r2_score of 86% which is really good.

# %%
x['Predicted_price'] = model.predict(x)
x
# Out:
#       Age_08_04        KM  Fuel_Type  HP  Automatic  cc  Doors  Gears  \
# 0     -1.777268 -0.767351          1   5          0  11      1      2
# 1     -1.777268 -0.767351          1   5          0  11      1      2
# 2     -1.723380 -0.767351          1   5          0  11      1      2
# 3     -1.615603 -0.767351          1   5          0  11      1      2
# 4     -1.400049 -0.767351          1   5          0  11      1      2
# ...         ...       ...        ...  ..        ...  ..    ...    ...
# 1431   0.701602 -1.034441          2   4          0   0      1      2
# 1432   0.863267 -1.034441          2   4          0   0      1      2
# 1433   0.809379 -1.034441          2   4          0   0      1      2
# 1434   0.755490 -1.034441          2   4          0   0      1      2
# 1435   1.078821  0.568103          2   9          0   6      3      2
#
#         Weight  Predicted_price
# 0     1.774964     15693.972930
# 1     1.774964     15693.972930
# ...

# %%
y
# Out:
# 0       13500
# 1       13750
# 2       13950
# 3       14950
# 4       13750
#         ...
# 1431     7500
# 1432    10845
# 1433     8500
# 1434     7250
# 1435     6950
# Name: Price, Length: 1435, dtype: int64

# %%
print('Equation of Linear regression prediction is y = b0+b1x1+....bixi')
print('coefficients of the model are : ')
print(f"b0: {model.coef_[0]} , b1: {model.coef_[1]}, b2: {model.coef_[2]}, b3: {model.coef_[3]}, b4: {model.coef_[4]}, b5: {model.coef_[5]}, b6: {model.coef_[6]}, b7: {model.coef_[7]}, b8: {model.coef_[8]}")
# Out:
# Equation of Linear regression prediction is y = b0+b1x1+....bixi
# coefficients of the model are :
# b0: -2626.365431755113 , b1: 541.9947240759717, b2: 669.7171724183256, b3: 8.471542675002237, b4: 357.0235590729099, b5: -137.00413169344492, b6: -61.981428032012346, b7: 332.8369370824702, b8: 1187.0523172948897

# %% [markdown]
# # Second Model

# %%
X = df_norm[['Weight','Age_08_04']]
Y = df_norm['Price']
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,random_state=0)
X
# Out:
#         Weight  Age_08_04
# 0     1.774964  -1.777268
# 1     1.774964  -1.777268
# 2     1.774964  -1.723380
# 3     1.774964  -1.615603
# 4     1.870688  -1.400049
# ...        ...        ...
# 1431 -0.905299   0.701602
# 1432 -1.096747   0.863267
# 1433 -1.096747   0.809379
# 1434 -1.096747   0.755490
# 1435  0.798582   1.078821
#
# [1435 rows x 2 columns]

# %%
import statsmodels.formula.api as smf
model = smf.ols('Price~Age_08_04+Weight',data = df_norm).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     2929.
# Date:                Tue, 10 Jun 2025   Prob (F-statistic):               0.00
# Time:                        16:26:32   Log-Likelihood:                -12622.
# No. Observations:                1435   AIC:                         2.525e+04
# Df Residuals:                    1432   BIC:                         2.527e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.072e+04     42.254    253.728      0.000    1.06e+04    1.08e+04
# ...

# %%
model.params
# Out:
# Intercept    10720.915679
# Age_08_04    -2801.719413
# Weight         770.476507
# dtype: float64

# %%
Price_2 = model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(Price_2,Y_test)
# Out:
# 0.7678184655863253

# %%
X_test['Price Predicted']= Price_2
X_test
# Out:
#         Weight  Age_08_04  Price Predicted
# 652   0.702859   0.378271     10202.643093
# 412   1.296346  -0.430056     12924.616691
# 343  -0.235233  -0.807276     12801.433754
# 1298 -0.426681   1.186598      7067.653505
# 484  -0.905299  -0.106725     10322.418658
# ...        ...        ...              ...
# 1047  0.798582   1.240486      7860.709662
# 1014 -0.139510   0.486048      9251.657179
# 521  -0.522405  -0.268391     11070.371259
# 995  -0.426681   0.647713      8577.457434
# 334  -0.235233  -1.184495     13858.296505
#
# [287 rows x 3 columns]

# %%
# R_Square is 76% which is pretty good.

# %% [markdown]
# # Third Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X = df_norm[['Age_08_04','Weight','KM']]
Y = df_norm['Price']
x_Train,x_Test,y_Train,y_Test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
m = LinearRegression()
m.fit(x_Train,y_Train)
Price_predicted = m.predict(x_Test)

# %%
r2_score(Price_predicted,y_Test)
# Out:
# 0.8384390660495814

# %%
# 83% which is also a good r2_score

# %%
print(f'Age: {m.coef_[0]}, Weight: {m.coef_[1]}, KM: {m.coef_[2]}')
# Out:
# Age: -2728.6138350180277, Weight: 767.5003928555008, KM: 625.1569258588763

# %%
X['Price_Predicted']=m.predict(X)
X
# Out:
#       Age_08_04    Weight        KM  Price_Predicted
# 0     -1.777268  1.774964 -0.767351     16444.934344
# 1     -1.777268  1.774964 -0.767351     16444.934344
# 2     -1.723380  1.774964 -0.767351     16297.893500
# 3     -1.615603  1.774964 -0.767351     16003.811811
# 4     -1.400049  1.870688 -0.767351     15489.116403
# ...         ...       ...       ...              ...
# 1431   0.701602 -0.905299 -1.034441      7456.978716
# 1432   0.863267 -1.096747 -1.034441      6868.920241
# 1433   0.809379 -1.096747 -1.034441      7015.961085
# 1434   0.755490 -1.096747 -1.034441      7163.001930
# 1435   1.078821  0.798582  0.568103      8737.264233
#
# [1435 rows x 4 columns]

# %% [markdown]
# # Lasso and Ridge methods

# %%
from sklearn.model_selection import train_test_split
x = df_norm.drop(columns='Price')
y = df_norm['Price']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error
lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
print(r2_score(y_pred,y_test))
print(mean_absolute_error(y_pred,y_test))
# Out:
# 0.8679043725227985
# 951.4779866391068

# %%
lreg_coef = pd.DataFrame()
lreg_coef['Columns']=x_train.columns
lreg_coef['Coefficient Estimate'] = pd.Series(lr.coef_)
print(lreg_coef)
# Out:
#      Columns  Coefficient Estimate
# 0  Age_08_04          -2626.365432
# 1         KM            541.994724
# 2  Fuel_Type            669.717172
# 3         HP              8.471543
# 4  Automatic            357.023559
# 5         cc           -137.004132
# 6      Doors            -61.981428
# 7      Gears            332.836937
# 8     Weight           1187.052317

# %%
import seaborn as sns
sns.barplot(x='Coefficient Estimate',y='Columns',data=lreg_coef)
plt.show()

# %%
# As we can see Age is most important feature for price prediction.

# %% [markdown]
# # Let us apply Lasso Regularisation to this model.

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score, mean_absolute_error
lasso = Lasso(alpha = 0.1)
lasso.fit(x_train,y_train)
y_pred_lasso = lasso.predict(x_test)
print(r2_score(y_pred_lasso,y_test))
print(mean_absolute_error(y_pred_lasso,y_test))
# Out:
# 0.8678808936093695
# 951.559448712389

# %%
# Lasso method gives us the same result as

# %%
lasso_coef = pd.DataFrame()
lasso_coef['Columns'] = x_train.columns
lasso_coef['Coefficient Estimate'] = pd.Series(lasso.coef_)
print(lasso_coef)
# Out:
#      Columns  Coefficient Estimate
# 0  Age_08_04          -2626.282693
# 1         KM            542.300659
# 2  Fuel_Type            668.082446
# 3         HP              8.506958
# 4  Automatic            354.822665
# 5         cc           -137.084290
# 6      Doors            -61.925384
# 7      Gears            330.030223
# 8     Weight           1186.831677

# %%
import seaborn as sns
sns.barplot(x='Coefficient Estimate',y='Columns',data=lasso_coef)
plt.show()

# %%
# Age is the most important feature for predicting price followed by Weight and Fuel Type.

# %% [markdown]
# # Lets apply Ridge method

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score, mean_absolute_error
ridge = Ridge(alpha=5)
ridge.fit(x_train,y_train)
y_pred_ridge=ridge.predict(x_test)
print(r2_score(y_pred_ridge,y_test))
print(mean_absolute_error(y_pred_ridge,y_test))
# Out:
# 0.8663837760345692
# 953.3297283640401

# %%
ridge_coef = pd.DataFrame()
ridge_coef['Columns'] = x_train.columns
ridge_coef['Coefficient Estimate'] = pd.Series(ridge.coef_)
print(ridge_coef)
# Out:
#      Columns  Coefficient Estimate
# 0  Age_08_04          -2615.405737
# 1         KM            536.714479
# 2  Fuel_Type            609.902857
# 3         HP             15.814159
# 4  Automatic            325.811540
# 5         cc           -141.002060
# 6      Doors            -60.926137
# 7      Gears            303.185052
# 8     Weight           1183.226421

# %%
import seaborn as sns
sns.barplot(x='Coefficient Estimate',y='Columns',data=ridge_coef)
plt.show()

# %%
# Age is the most important feature for predicting price followed by Weight and Fuel Type.

# %% [markdown]
# # Interview Questions:
# # 1.What is Normalization & Standardization and how is it helpful?
# # 2.What techniques can be used to address multicollinearity in multiple linear regression?

# %% [raw]
# 1. Normalization and Standardisation are data preprocessing techniques used to transform features so that machine learning models can perform better.
#    Techniques like Normalization and Standardisation are useful when the data set contains variables with different magnitudes. These techniques            converts those variables with different magnitudes to values ranging from 0 to 1 for Normalization and -3 to +3 for Standardization.

# %% [raw]
# 2. To address multicollinearity in multiple linear regression, several techniques can be employed. These include removing redundant variables,             combining correlated variables, using regularization techniques like Ridge or Lasso regression, collecting more data, and applying Principal            Component Analysis (PCA), etc.
#    VIF can be used to identify highly correlated variables. If the VIF of a variable is high, it suggests that the variable is strongly predicted by       other independent variables.
