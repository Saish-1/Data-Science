# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel("EastWestAirlines copy.xlsx")
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
plt.bar(df['cc1_miles'].unique(),df['cc1_miles'].value_counts())
plt.title('Bar Chart of cc1 Miles')
plt.xlabel('Number of miles earned with freq. flyer credit card in the past 12 months')
plt.ylabel('Passengers')
plt.show()

# %%
sns.barplot(df['Award?'].value_counts())
plt.title('BarChart of Award')
plt.ylabel('Passengers')
plt.xlabel('Last Award Received')
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
sns.boxplot(df['Balance'])
plt.title('Boxplot of Balance')
plt.show()

# %%
sns.histplot(df['Bonus_trans'])
plt.title('Number of non-flight bonus transactions in the past 12 months')
plt.ylabel('Frequency')
plt.show()

# %%
sns.violinplot(df['Flight_trans_12'])
plt.title('Violinplot of Flight transactions')
plt.ylabel('Number of Flight Transactions')
plt.show()

# %%
plt.boxplot(df['Qual_miles'])
plt.title('Number of miles counted as qualifying for Topflight status')
plt.show()

# %%
sns.histplot(df['Days_since_enroll'],edgecolor='black',color='teal')
plt.title('Number of days since Enroll_date')
plt.xlabel('No. of Days')
plt.ylabel('Passengers')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_norm = scaler.fit_transform(df)

# %%
df_norm
# Out:
# array([[0.00000000e+00, 1.65077268e-02, 0.00000000e+00, ...,
#         0.00000000e+00, 8.43742464e-01, 0.00000000e+00],
#        [2.48756219e-04, 1.12878760e-02, 0.00000000e+00, ...,
#         0.00000000e+00, 8.39884254e-01, 0.00000000e+00],
#        [4.97512438e-04, 2.42568502e-02, 0.00000000e+00, ...,
#         0.00000000e+00, 8.47841813e-01, 0.00000000e+00],
#        ...,
#        [9.99502488e-01, 4.31694976e-02, 0.00000000e+00, ...,
#         0.00000000e+00, 1.68796721e-01, 1.00000000e+00],
#        [9.99751244e-01, 3.22018866e-02, 0.00000000e+00, ...,
#         1.88679245e-02, 1.68676151e-01, 0.00000000e+00],
#        [1.00000000e+00, 1.76908304e-03, 0.00000000e+00, ...,
#         0.00000000e+00, 1.68314444e-01, 0.00000000e+00]])

# %%
df_norm = pd.DataFrame(df_norm)

# %%
#df1.columns = ['ID#','Balance','Qual_miles','cc1_miles','cc2_miles','cc3_miles','Bonus_miles','Bonus_trans','Flight_miles_12mo','Flight_trans_12','Days_since_enroll','Award?']
df_norm.columns = df.columns
df_norm
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     0.000000  0.016508         0.0       0.00        0.0        0.0
# 1     0.000249  0.011288         0.0       0.00        0.0        0.0
# 2     0.000498  0.024257         0.0       0.00        0.0        0.0
# 3     0.000746  0.008667         0.0       0.00        0.0        0.0
# 4     0.000995  0.057338         0.0       0.75        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994  0.999005  0.010837         0.0       0.00        0.0        0.0
# 3995  0.999254  0.037766         0.0       0.00        0.0        0.0
# 3996  0.999502  0.043169         0.0       0.50        0.0        0.0
# 3997  0.999751  0.032202         0.0       0.00        0.0        0.0
# 3998  1.000000  0.001769         0.0       0.00        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
df1 = df_norm.copy() # creating a new dataframe so that the normalised dataframe is saved for future uses.

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters = 3).fit(df1)
cluster_names = model.predict(df1)

# %%
cluster_names
# Out:
# array([2, 2, 2, ..., 0, 1, 1])

# %%
from sklearn.metrics import silhouette_score
silhouette_score(df_norm,cluster_names)
# Out:
# 0.39192300832091903

# %%
model.inertia_
# Out:
# 865.2628279924613

# %%
WCSS = []
for i in range(1,11):
    model = KMeans(n_clusters = i).fit(df_norm)
    WCSS.append(model.inertia_)

# %%
plt.title('Elbow Method')
plt.plot(range(1,11),WCSS)
figure = plt.figure(figsize=(8,6))
plt.show()

# %%
# number of clusters can be changed to 4-6 clusters.

# %%
model = KMeans(n_clusters = 5)
clusters = model.fit_predict(df_norm)
clusters
# Out:
# array([1, 1, 1, ..., 0, 4, 4])

# %%
df1['cluster_name'] = clusters

# %%
df1
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     0.000000  0.016508         0.0       0.00        0.0        0.0
# 1     0.000249  0.011288         0.0       0.00        0.0        0.0
# 2     0.000498  0.024257         0.0       0.00        0.0        0.0
# 3     0.000746  0.008667         0.0       0.00        0.0        0.0
# 4     0.000995  0.057338         0.0       0.75        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994  0.999005  0.010837         0.0       0.00        0.0        0.0
# 3995  0.999254  0.037766         0.0       0.00        0.0        0.0
# 3996  0.999502  0.043169         0.0       0.50        0.0        0.0
# 3997  0.999751  0.032202         0.0       0.00        0.0        0.0
# 3998  1.000000  0.001769         0.0       0.00        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
model.inertia_
# Out:
# 536.2034790432668

# %%
df1.plot("Days_since_enroll","Qual_miles", c = model.labels_,kind='scatter',s=50, cmap ='plasma',edgecolor='black')
# Out:
# <Axes: xlabel='Days_since_enroll', ylabel='Qual_miles'>

# %%
silhouette_score(df1,clusters)
# Out:
# 0.696051267252434

# %%
# Heirarchical Clustering
from sklearn.cluster import AgglomerativeClustering
hc_model = AgglomerativeClustering(n_clusters = 4 , linkage = 'average' , metric = 'euclidean')

# %%
df2 = df_norm.copy()

# %%
Clusters = hc_model.fit_predict(df2)
Clusters
# Out:
# array([2, 2, 2, ..., 1, 2, 2], dtype=int64)

# %%
import scipy.cluster.hierarchy as sch #for dendrogram
dendogram = sch.dendrogram(sch.linkage(df2,method='average'),labels=df2.index)
figure = plt.figure(figsize = (20,5))

# %%
#as the data is very large we will not use hierarchical clustering.

# %%
df3 = df_norm.copy()
df3
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     0.000000  0.016508         0.0       0.00        0.0        0.0
# 1     0.000249  0.011288         0.0       0.00        0.0        0.0
# 2     0.000498  0.024257         0.0       0.00        0.0        0.0
# 3     0.000746  0.008667         0.0       0.00        0.0        0.0
# 4     0.000995  0.057338         0.0       0.75        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994  0.999005  0.010837         0.0       0.00        0.0        0.0
# 3995  0.999254  0.037766         0.0       0.00        0.0        0.0
# 3996  0.999502  0.043169         0.0       0.50        0.0        0.0
# 3997  0.999751  0.032202         0.0       0.00        0.0        0.0
# 3998  1.000000  0.001769         0.0       0.00        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
# DBScan 
from sklearn.cluster import DBSCAN 
model_dbscan = DBSCAN(eps=1,min_samples = 5)
Cluster_name = model_dbscan.fit_predict(df3)
Cluster_name
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
df3['Clusters'] = Cluster_name
df3
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     0.000000  0.016508         0.0       0.00        0.0        0.0
# 1     0.000249  0.011288         0.0       0.00        0.0        0.0
# 2     0.000498  0.024257         0.0       0.00        0.0        0.0
# 3     0.000746  0.008667         0.0       0.00        0.0        0.0
# 4     0.000995  0.057338         0.0       0.75        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994  0.999005  0.010837         0.0       0.00        0.0        0.0
# 3995  0.999254  0.037766         0.0       0.00        0.0        0.0
# 3996  0.999502  0.043169         0.0       0.50        0.0        0.0
# 3997  0.999751  0.032202         0.0       0.00        0.0        0.0
# 3998  1.000000  0.001769         0.0       0.00        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
df3['Clusters'].value_counts()
# Out:
# Clusters
# 0    2518
# 1    1481
# Name: count, dtype: int64

# %%
df.plot('Bonus_trans','Days_since_enroll',kind = 'scatter',c = Cluster_name, cmap = 'plasma',edgecolor='black')
# Out:
# <Axes: xlabel='Bonus_trans', ylabel='Days_since_enroll'>

# %%
silhouette_score(df1,clusters)
# Out:
# 0.696051267252434
